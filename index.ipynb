# %%
import funciones.frecuencias as v
import funciones.ordenar as c
import funciones.ordenar_clases as am
import funciones.frecuencia_re as s
import funciones.frecuencia_ac as l
import funciones.ordenar_cad as z
import funciones.formatear as ca
import funciones.indices as i
import funciones.tabla_letras as t
import funciones.pie as pie

# %%
lista = ["ramirez","rodriguez","hernandez","hernandez", "rodriguez","rodriguez",
"gonzalez","gonzalez","ramirez","hernandez", "garcia","martinez","lopez","gonzalez","martinez","lopez",
"lopez","gonzalez","gutierrez","martinez","gonzalez","rodriguez","perez","rodriguez","ramirez","sanchez",
"martinez","lopez","sanchez","garcia","rodriguez","hernandez","gonzalez","sanchez","perez","rodriguez",
"lopez","martinez","flores","hernandez", "perez","garcia","martinez","hernandez", 
"sanchez","ramirez","garcia","gonzalez","garcia","flores","martinez","garcia",
"ramirez","gonzalez","hernandez","lopez","sanchez","martinez","martinez","perez","garcia","gonzalez",
"garcia","gutierrez","hernandez", "martinez","garcia","hernandez", "garcia","gonzalez","lopez","hernandez", "rodriguez",
"martinez","gonzalez",
        ]

datos_nuevos= ca.formateando_str(lista)
ordenadas=z.ordenar_cadenas(datos_nuevos) 
clases, fa_absoluta= v.frec_abs(ordenadas)
clases_sorted = c.ordenar_asc(clases)
fa_sorted = am.sort_clases_fa(clases, clases_sorted, fa_absoluta)
print ("Clases: ", clases_sorted)
print("Frec. absoluta: ", fa_sorted)
frecuencia_relativa = s.obtener_frecuencia_relativa(fa_sorted)
print("Frecuencia relativa:", frecuencia_relativa)
frecuencia_relativa_acumulada=l.obtener_frecuencia_relativa_acumulada(frecuencia_relativa)
print("Frecuencia relativa acumulada:", frecuencia_relativa_acumulada)
marcas_clases= i.obtener_indices(clases)
print()
print()
tabla=t.generar_tabla(clases, fa_sorted, frecuencia_relativa, frecuencia_relativa_acumulada)
print()
print()

titulo = "Apellidos"
pie.generar_pastel(clases_sorted, fa_sorted, titulo)
# Out:
# Clases:  ['FLORES', 'GARCIA', 'GONZALEZ', 'GUTIERREZ', 'HERNANDEZ', 'LOPEZ', 'MARTINEZ', 'PEREZ', 'RAMIREZ', 'RODRIGUEZ', 'SANCHEZ']
# Frec. absoluta:  [2, 10, 11, 2, 10, 7, 11, 4, 5, 8, 5]
# Frecuencia relativa: [2.666666666666667, 13.333333333333334, 14.666666666666666, 2.666666666666667, 13.333333333333334, 9.333333333333334, 14.666666666666666, 5.333333333333334, 6.666666666666667, 10.666666666666668, 6.666666666666667]
# Frecuencia relativa acumulada: [2.666666666666667, 16.0, 30.666666666666664, 33.33333333333333, 46.666666666666664, 56.0, 70.66666666666667, 76.0, 82.66666666666667, 93.33333333333334, 100.00000000000001]
#
#
#        Clases  Frecuencia absoluta  Frecuencia relativa  Frecuencia relativa acumulada
# 0      FLORES                    2             2.666667                       2.666667
# 1      GARCIA                   10            13.333333                      16.000000
# 2    GONZALEZ                   11            14.666667                      30.666667
# 3   GUTIERREZ                    2             2.666667                      33.333333
# 4   HERNANDEZ                   10            13.333333                      46.666667
# 5       LOPEZ                    7             9.333333                      56.000000
# 6    MARTINEZ                   11            14.666667                      70.666667
# 7       PEREZ                    4             5.333333                      76.000000
# 8     RAMIREZ                    5             6.666667                      82.666667
# 9   RODRIGUEZ                    8            10.666667                      93.333333
# 10    SANCHEZ                    5             6.666667                     100.000000

# %%
"garcia"
"hernandez" 
"ramirez"
"flores"
"hernandez" 
"gutierrez"
"garcia"
"hernandez" 
"gonzalez"
"garcia"
"garcia"
"flores"
"lopez"
"perez"
"sanchez"
"lopez"
"gutierrez"
"sanchez"
"rodriguez"
"hernandez"
"hernandez" 
"perez"
"sanchez"
"lopez"
"martinez"
