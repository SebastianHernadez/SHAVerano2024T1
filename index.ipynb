# %%
import funciones.frecuencias as v
import funciones.ordenar as c
import funciones.ordenar_clases as am
import funciones.frecuencia_re as s
import funciones.frecuencia_ac as l
import funciones.ordenar_cad as z
import funciones.formatear as ca
import funciones.indices as i
import funciones.tabla_letras as t

# %%
lista = ["",]

datos_nuevos= ca.formateando_str(lista)
ordenadas=z.ordenar_cadenas(datos_nuevos) 
clases, fa_absoluta= v.frec_abs(ordenadas)
clases_sorted = c.ordenar_asc(clases)
fa_sorted = am.sort_clases_fa(clases, clases_sorted, fa_absoluta)
print ("Clases: ", clases_sorted)
print("Frec. absoluta: ", fa_sorted)
frecuencia_relativa = s.obtener_frecuencia_relativa(fa_sorted)
print("Frecuencia relativa:", frecuencia_relativa)
frecuencia_relativa_acumulada=l.obtener_frecuencia_relativa_acumulada(frecuencia_relativa)
print("Frecuencia relativa acumulada:", frecuencia_relativa_acumulada)
marcas_clases= i.obtener_indices(clases)
print()
print()
tabla=t.generar_tabla(clases, fa_sorted, frecuencia_relativa, frecuencia_relativa_acumulada)
print()
print()
# Out:
# Clases:  ['COLA', 'COLALIGHT', 'LIMON', 'MANZANA', 'NARANJA', 'TORONJA']
# Frec. absoluta:  [9, 6, 4, 3, 3, 5]
# Frecuencia relativa: [30.0, 20.0, 13.333333333333334, 10.0, 10.0, 16.666666666666664]
# Frecuencia relativa acumulada: [30.0, 50.0, 63.333333333333336, 73.33333333333334, 83.33333333333334, 100.0]
#
#
#       Clases  Frecuencia absoluta  Frecuencia relativa  Frecuencia relativa acumulada
# 0       COLA                    9            30.000000                      30.000000
# 1  COLALIGHT                    6            20.000000                      50.000000
# 2      LIMON                    4            13.333333                      63.333333
# 3    MANZANA                    3            10.000000                      73.333333
# 4    NARANJA                    3            10.000000                      83.333333
# 5    TORONJA                    5            16.666667                     100.000000

# %%
ramirez
rodriguez
hernandez 
hernandez 
rodriguez
rodriguez
gonzalez
gonzalez
ramirez
hernandez 
garcia
martinez
lopez
gonzalez
martinez
lopez
lopez
gonzalez
gutierrez
martinez
gonzalez
rodriguez
perez
rodriguez
ramirez
sanchez
martinez
lopez
sanchez
garcia
rodriguez
hernandez 
gonzalez
sanchez
perez
rodriguez
lopez
martinez
flores
hernandez 
perez
garcia
martinez
hernandez 
sanchez
ramirez
garcia
gonzalez
garcia
flores
martinez
garcia
ramirez
gonzalez
hernandez 
lopez
sanchez
martinez
martinez
perez
garcia
gonzalez
garcia
gutierrez
hernandez 
martinez
garcia
hernandez 
garcia
gonzalez
lopez
hernandez 
rodriguez
martinez
gonzalez
garcia
hernandez 
ramirez
flores
hernandez 
gutierrez
garcia
hernandez 
gonzalez
garcia
garcia
flores
lopez
perez
sanchez
lopez
gutierrez
sanchez
rodriguez
hernandez 
hernandez 
perez
sanchez
lopez
martinez
