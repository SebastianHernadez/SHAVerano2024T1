# %%
import funciones.frecuencias as v
import funciones.ordenar as c
import funciones.ordenar_clases as am
import funciones.frecuencia_re as s
import funciones.frecuencia_ac as l
import funciones.ordenar_cad as z
import funciones.formatear as ca
import funciones.indices as i
import funciones.tabla_letras as t
import funciones.pie as pie

# %%
lista = ["ramirez",
"rodriguez",
"hernandez",
"hernandez", 
"rodriguez",
"rodriguez",
"gonzalez",
"gonzalez",
"ramirez",
"hernandez", 
"garcia",
"martinez",
"lopez",
"gonzalez",
"martinez",
"lopez",
"lopez",
"gonzalez",
"gutierrez",
"martinez",
"gonzalez",
"rodriguez",
"perez",
"rodriguez",
"ramirez",
"sanchez"]

datos_nuevos= ca.formateando_str(lista)
ordenadas=z.ordenar_cadenas(datos_nuevos) 
clases, fa_absoluta= v.frec_abs(ordenadas)
clases_sorted = c.ordenar_asc(clases)
fa_sorted = am.sort_clases_fa(clases, clases_sorted, fa_absoluta)
print ("Clases: ", clases_sorted)
print("Frec. absoluta: ", fa_sorted)
frecuencia_relativa = s.obtener_frecuencia_relativa(fa_sorted)
print("Frecuencia relativa:", frecuencia_relativa)
frecuencia_relativa_acumulada=l.obtener_frecuencia_relativa_acumulada(frecuencia_relativa)
print("Frecuencia relativa acumulada:", frecuencia_relativa_acumulada)
marcas_clases= i.obtener_indices(clases)
print()
print()
tabla=t.generar_tabla(clases, fa_sorted, frecuencia_relativa, frecuencia_relativa_acumulada)
print()
print()

titulo = "Apellidos"
pie.generar_pastel(clases_sorted, fa_sorted, titulo)
# Out:
# Clases:  ['GARCIA', 'GONZALEZ', 'GUTIERREZ', 'HERNANDEZ', 'LOPEZ', 'MARTINEZ', 'PEREZ', 'RAMIREZ', 'RODRIGUEZ', 'SANCHEZ']
# Frec. absoluta:  [1, 5, 1, 3, 3, 3, 1, 3, 5, 1]
# Frecuencia relativa: [3.8461538461538463, 19.230769230769234, 3.8461538461538463, 11.538461538461538, 11.538461538461538, 11.538461538461538, 3.8461538461538463, 11.538461538461538, 19.230769230769234, 3.8461538461538463]
# Frecuencia relativa acumulada: [3.8461538461538463, 23.07692307692308, 26.923076923076927, 38.46153846153847, 50.00000000000001, 61.53846153846155, 65.38461538461539, 76.92307692307692, 96.15384615384616, 100.0]
#
#
#       Clases  Frecuencia absoluta  Frecuencia relativa  Frecuencia relativa acumulada
# 0     GARCIA                    1             3.846154                       3.846154
# 1   GONZALEZ                    5            19.230769                      23.076923
# 2  GUTIERREZ                    1             3.846154                      26.923077
# 3  HERNANDEZ                    3            11.538462                      38.461538
# 4      LOPEZ                    3            11.538462                      50.000000
# 5   MARTINEZ                    3            11.538462                      61.538462
# 6      PEREZ                    1             3.846154                      65.384615
# 7    RAMIREZ                    3            11.538462                      76.923077
# 8  RODRIGUEZ                    5            19.230769                      96.153846
# 9    SANCHEZ                    1             3.846154                     100.000000

# %%
martinez"
lopez"
sanchez"
garcia"
rodriguez"
hernandez"
gonzalez"
sanchez"
perez"
rodriguez"
lopez"
martinez"
flores"
hernandez" 
perez"
garcia"
martinez"
hernandez" 
sanchez"
ramirez"
garcia"
gonzalez"
garcia"
flores"
martinez
garcia
ramirez
gonzalez
hernandez 
lopez
sanchez
martinez
martinez
perez
garcia
gonzalez
garcia
gutierrez
hernandez 
martinez
garcia
hernandez 
garcia
gonzalez
lopez
hernandez 
rodriguez
martinez
gonzalez
garcia
hernandez 
ramirez
flores
hernandez 
gutierrez
garcia
hernandez 
gonzalez
garcia
garcia
flores
lopez
perez
sanchez
lopez
gutierrez
sanchez
rodriguez
hernandez 
hernandez 
perez
sanchez
lopez
martinez
